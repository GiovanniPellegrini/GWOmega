# %%
# %load_ext autoreload
# %autoreload 2
from likelihood_triangular import run_pe_triangula_RD, run_pe_triangular_eMD
from likelihood_2L import run_pe_2L_RD, run_pe_2L_eMD
import numpy as np
from data_generation_triangular import create_data_files_triangular_RD, create_data_files_triangular_eMD
from data_generation_2L import create_data_files_2L_RD, create_data_files_2L_eMD, create_C_hat_2L_RD
from Omega import compute_Omega_RD_today_fast, P_k_lognormal, compute_Omega_RD_today
import constants
from tqdm import tqdm
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
Tobs=60*60*24*365
Tseg=10

run_pe_2L_RD(A_s=10**(-2.5) , k_peak=100, sigma=0.3, T_obs=Tobs, N_seg=int(Tobs/Tseg), outdir='outputs/2L_RD_365D_sigma03', C_hat_filename='data/2L/v2/2L_RD_365D_sigma03.h5', parameters_filename='data/2L/v2/parameters_2L_RD_365D_sigma03.txt')
# Out:
# time for each segment: 10.0
# number of segments: 3153600
# total observation time (s): 31536000
# SNR ET RD: 113.95
# Parameters loaded from data/2L/v2/parameters_2L_RD_365D_sigma03.txt
# All parameters match.
# C_hat data loaded from data/2L/v2/2L_RD_365D_sigma03.h5
# C_hat shape: (1991,)
# 18:08 bilby INFO    : Running for label 'estimator RD_A0.0032_sigma0.3_kpeak100.0_Tobs8760.0hr_Tseg10.0sec', output will be saved to 'outputs/2L_RD_365D_sigma03'
# 18:08 bilby INFO    : Analysis priors:
# 18:08 bilby INFO    : A_s=LogUniform(minimum=0.0001, maximum=0.05, name='$A_s$', latex_label='$A_s$', unit=None, boundary=None)
# 18:08 bilby INFO    : sigma=Uniform(minimum=0.01, maximum=1, name='$\\sigma$', latex_label='$\\sigma$', unit=None, boundary=None)
# 18:08 bilby INFO    : k_peak=Uniform(minimum=6.283185307179586, maximum=1884.9555921538758, name='$k_{peak}$', latex_label='$k_{peak}$', unit=None, boundary=None)
# ...

# %%
Tobs=60*60*24*365
Tseg=10

run_pe_triangula_RD(A_s=10**(-2.5), k_peak=100, sigma=0.3, r=0.2, n_noise=-8, T_obs=Tobs, N_seg=int(Tobs/Tseg), outdir='outputs/run2/triangular_RD_365D_sigma03', C_hat_filename='data/Triangular/v2/triangular_RD_365D_sigma03.h5', parameters_filename='data/Triangular/v2/parameters_triangular_RD_365D_sigma03.txt')
# Out:
# time for each segment: 10.0
# number of segments: 3153600
# total observation time (s): 31536000
# SNR ET RD: 113.95
# Parameters loaded from data/Triangular/v2/parameters_triangular_RD_365D_sigma03.txt
# All parameters match.
# C_hat data loaded from data/Triangular/v2/triangular_RD_365D_sigma03.h5
# C_hat shape: (2, 1991)
# 19:37 bilby INFO    : Running for label 'estimator RD_A0.0_kpeak100.0_sigma0.30_r0.20_n-8.00_Tobs8760.0hr_Tseg10.0sec', output will be saved to 'outputs/run2/triangular_RD_365D_sigma03'
# 19:37 bilby INFO    : Analysis priors:
# 19:37 bilby INFO    : r=Uniform(minimum=-0.5, maximum=1, name='$r$', latex_label='$r$', unit=None, boundary=None)
# 19:37 bilby INFO    : n_noise=Uniform(minimum=-10, maximum=-5, name='$n_{\\text{noise}}$', latex_label='$n_{\\text{noise}}$', unit=None, boundary=None)
# 19:37 bilby INFO    : A_s=LogUniform(minimum=0.0001, maximum=0.05, name='$A_{\\text{s}}$', latex_label='$A_{\\text{s}}$', unit=None, boundary=None)
# ...

# %%
Tobs=60*60*24*365
Tseg=10

run_pe_2L_eMD(A_s=2.1*10**-9, k_max=20*np.pi, eta_R=120/(20*np.pi), T_obs=Tobs, N_seg=int(Tobs/Tseg), outdir='outputs/run2/2L_eMD_365D_constrain_120', C_hat_filename='data/2L/v2/C_hat_2L_eMD_365D_v2.h5', parameters_filename='data/2L/v2/parameters_2L_eMD_365D_v2.txt')
# Out:
# time for each segment: 10.0
# number of segments: 3153600
# total observation time (s): 31536000
# SNR ET eMD: 273.06
# Parameters loaded from data/2L/v2/parameters_2L_eMD_365D_v2.txt
# All parameters match.
# C_hat data loaded from data/2L/v2/C_hat_2L_eMD_365D_v2.h5
# C_hat shape: (1991,)
# 18:08 bilby INFO    : Running for label 'estimator RD_A0.0000_kmax62.8_xR120.0_Tobs8760.0hr_Tseg10.0sec', output will be saved to 'outputs/run2/2L_eMD_365D_constrain_120'
# 18:08 bilby INFO    : Analysis priors:
# 18:08 bilby INFO    : A_s=LogUniform(minimum=1e-10, maximum=1e-08, name='$A_{\\text{s}}$', latex_label='$A_{\\text{s}}$', unit=None, boundary=None)
# 18:08 bilby INFO    : k_max=Uniform(minimum=6.283185307179586, maximum=1884.9555921538758, name='$k_{\\text{max}}$', latex_label='$k_{\\text{max}}$', unit=None, boundary=None)
# ...

# %%
Tobs=60*60*24*365
Tseg=10

run_pe_triangular_eMD(A_s=2*10**-9, k_max=120, eta_R=0.96, r=0.2, n_noise=-8, T_obs=Tobs, N_seg=int(Tobs/Tseg), outdir='outputs/test_run_pe_triangular_eMD_365D', C_hat_filename='data/Triangular/v2/C_hat_aet_eMD_365D_v2.h5', parameters_filename='data/Triangular/v2/parameters_aet_eMD_365D_v2.txt')
# Out:
# time for each segment: 10.0
# number of segments: 3153600
# total observation time (s): 31536000
# SNR ET RD: 70.05
# Parameters loaded from data/Triangular/v2/parameters_aet_eMD_365D_v2.txt
# All parameters match.
# C_hat data loaded from data/Triangular/v2/C_hat_aet_eMD_365D_v2.h5
# C_hat shape: (2, 1991)
# 10:38 bilby INFO    : Running for label 'estimator eMD_A0.0_kmax120.0_eta_R0.96_r0.20_n-8.00_Tobs8760.0hr_Tseg10.0sec', output will be saved to 'outputs/test_run_pe_triangular_eMD_365D'
# Priors created successfully
# Testing prior sampling...
# Test sample: {'r': -0.23364509016092788, 'n_noise': -8.150110019053827, 'A_s': np.float64(2.165529605261599e-09), 'k_max': 166.58360503988666, 'eta_R': 2.821048587211965}
# 10:38 bilby INFO    : Analysis priors:
# 10:38 bilby INFO    : r=Uniform(minimum=-0.5, maximum=1, name='$r$', latex_label='$r$', unit=None, boundary=None)
# ...
